# %% [markdown]
# W1A1: Đoạn code này thực hiện một phép tính trừ cơ bản và in kết quả.
#
# a = 7
#
# Giải thích: Dòng này gán (lưu) giá trị số nguyên 7 vào một biến (một "hộp chứa" dữ liệu) có tên là a.
#
# b = 5
#
# Giải thích: Tương tự, dòng này gán giá trị số nguyên 5 vào biến có tên là b.
#
# c = a - b
#
# Giải thích: Dòng này thực hiện phép tính toán. Nó lấy giá trị hiện tại được lưu trong a (là 7) trừ đi giá trị hiện tại được lưu trong b (là 5).
#
# Phép tính là: 7 - 5 = 2.
#
# Kết quả của phép trừ (2) sau đó được gán vào một biến mới tên là c.
#
# print(c)
#
# Giải thích: Đây là lệnh "in". Nó yêu cầu máy tính hiển thị giá trị hiện đang được lưu trong biến c (là 2) ra màn hình.
#
# Vì sao ra kết quả 2? Kết quả là 2 vì chương trình đã lấy 7 (a) trừ đi 5 (b) và lưu kết quả (2) vào biến c, sau đó lệnh print(c) đã in đúng giá trị đó ra.

# %%
a = 7
b = 5
c = a - b
print(c)
# Out:
# 2

# %% [markdown]
# W1A2: Đoạn code Python này thực hiện việc khai báo hai biến (city và year) rồi in chúng ra màn hình kèm theo một số văn bản mô tả.
# Kết quả in ra chính xác sẽ là:
# Thành phố:  Hà Nội , Năm:  2025
# 💡 Giải thích code và kết quả
# Mục đích: Đoạn code này gán giá trị cho hai biến là city (thành phố) và year (năm). Sau đó, nó dùng hàm print() để in ra một chuỗi thông tin, kết hợp (ghép) các văn bản cố định với giá trị của hai biến đó.
# Vì sao ra kết quả như vậy? Hàm print() trong Python khi nhận nhiều đối số (các giá trị cách nhau bằng dấu phẩy ,) sẽ tự động thêm một ký tự dấu cách vào giữa mỗi đối số khi in chúng ra.
# Hãy xem xét 4 đối số bạn đã truyền vào hàm print():
# Chuỗi "Thành phố: " (chuỗi này đã có một dấu cách ở cuối)
# Biến city (có giá trị là "Hà Nội")
# Chuỗi ", Năm: " (chuỗi này bắt đầu bằng dấu phẩy, rồi dấu cách, rồi "Năm:", rồi dấu cách)
# Biến year (có giá trị là số 2025)
# Khi Python thực thi, nó sẽ in ra:
# (Đối số 1) "Thành phố: "
# (dấu cách tự động)
# (Đối số 2) "Hà Nội"
# (dấu cách tự động)
# (Đối số 3) ", Năm: "
# (dấu cách tự động)
# (Đối số 4) 2025 (số 2025 được tự động chuyển thành chuỗi)
# Ghép tất cả lại, chúng ta có: Thành phố: Hà Nội , Năm: 2025.
# 👩‍💻 Giải thích từng dòng code
# city = "Hà Nội"
# Dòng này khai báo một biến có tên là city.
# Toán tử = (phép gán) gán cho biến city giá trị là một chuỗi ký tự (string) "Hà Nội".
# year = 2025
# Dòng này khai báo một biến có tên là year.
# Nó gán cho biến year giá trị là một số nguyên (integer) 2025.
# print("Thành phố: ", city, ", Năm: ", year)
# Dòng này gọi hàm print() (một hàm tích hợp sẵn của Python) để xuất thông tin ra màn hình.
# Nó in ra 4 giá trị theo thứ tự, và tự động chèn một dấu cách vào giữa mỗi giá trị như đã giải thích ở trên.

# %%
city = "Hà Nội"
year = 2025
print("Thành phố: ", city,"- Năm: ",year)
# Out:
# Thành phố:  Hà Nội - Năm:  2025

# %% [markdown]
# W1A3: Đoạn code Python này thực hiện việc tính tổng các số nguyên liên tiếp từ 1 đến n (trong trường hợp này là 4).Kết quả in ra màn hình sẽ là 10.
# 💡 Giải thích code và kết quả
# 1. Công việc của đoạn code Đoạn code sử dụng một vòng lặp for để tính tổng tích lũy (tổng dồn) của các số nguyên dương bắt đầu từ 1 cho đến giá trị của biến n (bao gồm cả n).n = 4: Đây là giới hạn trên của phép tính tổng.t = 0: Đây là biến tích lũy, dùng để lưu trữ kết quả tổng qua mỗi vòng lặp.
# 2. Kết quả tính toán (10)Vòng lặp for i in range(1, n+1) sẽ thực hiện tính tổng các giá trị: 1 + 2 + 3 + 4. Sau khi vòng lặp kết thúc, hàm print(t) sẽ in ra giá trị cuối cùng của t là 10.
# 👩‍💻 Giải thích từng dòng code
# n = 4 Khai báo biến: Gán giá trị số nguyên 4 cho biến n. Biến này xác định số lượng số cần tính tổng (từ 1 đến 4).
# t = 0 Khai báo biến: Gán giá trị số nguyên 0 cho biến t (tổng/total). Đây là giá trị khởi tạo, nơi tổng các số sẽ được cộng dồn vào.
# for i in range(1, n+1): Vòng lặp for: Bắt đầu một vòng lặp.range(1, n+1): Hàm range() tạo ra một chuỗi số nguyên.Bắt đầu tại số 1.Kết thúc tại n+1 ($4+1=5$), nhưng không bao gồm số cuối cùng (tức là dừng lại ở 4).Do đó, vòng lặp này sẽ lặp 4 lần, với biến i lần lượt nhận các giá trị: 1, 2, 3, 4.
# t += i Thực hiện phép cộng dồn: Đây là cú pháp viết tắt cho t = t + i.Trong mỗi lần lặp, giá trị hiện tại của i sẽ được cộng thêm vào biến t.
# print(t) Kết quả cuối cùng: Sau khi vòng lặp kết thúc, hàm print() sẽ in giá trị cuối cùng của biến t ra màn hình.

# %%
n = 4
t = 0
for i in range(1, n+1):
    t += i
print(t)
# Out:
# 10

# %% [markdown]
# W1A4: Đoạn code Python này thực hiện việc kiểm tra và phân loại từng số trong danh sách numbers là số chẵn hay số lẻ.
# Kết quả in ra màn hình sẽ là:
# 1 là số lẻ
# 2 là số chẵn
# 3 là số lẻ
# 4 là số chẵn
# 💡 Giải thích code và kết quả
# 1. Công việc của đoạn codeCode này lặp qua từng phần tử (x) trong danh sách numbers = [1, 2, 3, 4]. Trong mỗi lần lặp, nó sử dụng phép toán chia lấy dư (%) để kiểm tra tính chẵn lẻ của số đó: Điều kiện kiểm tra: x % 2 == 0 Phép toán x % 2 trả về số dư khi x chia cho 2.Nếu số dư bằng 0 (== 0), nghĩa là x chia hết cho 2, nên x là số chẵn.Nếu số dư khác 0 (tức là bằng 1), nghĩa là x không chia hết cho 2, nên x là số lẻ.
# 2. Kết quả chi tiết
# Vòng lặp for sẽ lặp 4 lần, tương ứng với 4 phần tử
# 👩‍💻 Giải thích từng dòng code
# - numbers = [1, 2, 3, 4]Khai báo biến: Khai báo biến numbers và gán cho nó một list (danh sách) chứa các số nguyên 1, 2, 3, 4.
# - for x in numbers:Vòng lặp for: Bắt đầu vòng lặp. Nó sẽ lần lượt lấy từng phần tử trong danh sách numbers và gán giá trị đó cho biến x.
# - if x % 2 == 0:Cấu trúc điều kiện: Kiểm tra xem giá trị của x có phải là số chẵn hay không.: Là toán tử chia lấy dư (modulo).== 0: Kiểm tra xem số dư có bằng 0 hay không.
# - print(x, "là số chẵn")Dòng này được thực thi chỉ khi điều kiện if là đúng (số chẵn).Nó in ra giá trị của x, theo sau là chuỗi "là số chẵn".
# - else:Điều kiện thay thế: Phần else được thực thi chỉ khi điều kiện if là sai (số lẻ).
# - print(x, "là số lẻ")Dòng này được thực thi chỉ khi điều kiện if là sai.Nó in ra giá trị của x, theo sau là chuỗi "là số lẻ".

# %%
numbers = [1, 2, 3, 4]
for x in numbers:
    if x % 2 == 0:
        print(x, "là số chẵn")
    else:
        print(x, "là số lẻ")
# Out:
# 1 là số lẻ
# 2 là số chẵn
# 3 là số lẻ
# 4 là số chẵn

# %% [markdown]
# W1A5: Đoạn code này đếm số phần tử trong danh sách animals. Kết quả in ra sẽ là 4 vì danh sách có 4 phần tử: "cat", "dog", "cat", "bird".
# Giải thích từng dòng code:
# - animals = ["cat", "dog", "cat", "bird"] - Tạo danh sách với 4 phần tử
# - count = 0 - Khởi tạo biến đếm bằng 0
# - for a in animals: - Vòng lặp qua từng phần tử trong danh sách
# - count += 1 - Mỗi lần lặp, tăng biến đếm lên 1
# - print("Số phần tử trong danh sách là:", count) - In kết quả cuối cùng

# %%
animals = ["cat", "dog", "cat", "bird"]
count = 0
for a in animals:
    count += 1
    print("Số phần tử trong danh sách là:", count)
# Out:
# Số phần tử trong danh sách là: 1
# Số phần tử trong danh sách là: 2
# Số phần tử trong danh sách là: 3
# Số phần tử trong danh sách là: 4

# %% [markdown]
# W1A6: Đoạn mã này không phải là một đoạn code Python đang chạy mà là một giao diện hiển thị (hoặc một chuỗi output) của một chương trình máy tính. Chương trình này đang thực hiện công việc hiển thị một menu lựa chọn cho người dùng.
# 💡 Giải thích chương trình và ý nghĩa
# 1. Công việc của chương trình
# Chương trình đang chạy một hệ thống dự đoán AI (AI Prediction System) và cung cấp cho người dùng các chức năng cụ thể để lựa chọn:
# - Sentiment analysis (Phân tích cảm xúc): Đây là một tác vụ AI dùng để xác định thái độ, quan điểm, hoặc cảm xúc (tích cực, tiêu cực, trung lập) từ một đoạn văn bản hoặc dữ liệu nào đó.
# - Weather forecast (Dự báo thời tiết): Đây là một tác vụ dự đoán dựa trên dữ liệu, thường sử dụng mô hình AI hoặc các mô hình toán học phức tạp để dự báo tình trạng thời tiết.
# - Exit (Thoát): Cho phép người dùng kết thúc chương trình.
# Dòng cuối cùng "Please choose an option:" (Vui lòng chọn một tùy chọn:) là một lời nhắc để người dùng nhập số (1, 2, hoặc 3) tương ứng với chức năng mà họ muốn sử dụng.
# 2. Vì sao có kết quả như vậy
# Kết quả (giao diện menu này) được tạo ra là do:
# - Mục đích: Chương trình được thiết kế để trở thành một hệ thống đa chức năng. Việc hiển thị menu là bước đầu tiên để tương tác với người dùng, giúp người dùng biết được chương trình có thể làm gì và lựa chọn tác vụ phù hợp.
# - Hàm print()/Lệnh hiển thị: Trong hầu hết các ngôn ngữ lập trình (như Python, Java, C++), chương trình sẽ sử dụng các lệnh xuất dữ liệu ra màn hình (ví dụ: lệnh print() trong Python) để hiển thị các dòng chữ này theo thứ tự: tiêu đề, các lựa chọn được đánh số, và lời nhắc nhập liệu.

# %%
=== AI Prediction System ===
1) Sentiment Analysis
2) Weather Forecast
3) Exit
Please choose an option:

# %% [markdown]
# W1A7: Đoạn code này phân loại số chẵn/lẻ với lỗi logic. Code hiện tại sai vì:
# Lỗi trong code:
# num = input("Nhập số: ")
# if num % 2 == 0:  # LỖI: không thể dùng % với string
#     print("Số chẵn")
# else:
#     print("Số lẻ")
# Vấn đề: input() trả về chuỗi (string), không thể dùng toán tử % (chia lấy dư) với string.
# Code đúng sau khi AI sửa:
# num = int(input("Nhập số: "))  # Chuyển sang số nguyên
# if num % 2 == 0:
#     print("Số chẵn")
# else:
#     print("Số lẻ")

# %%
num = int(input("Nhập số: "))
if num % 2 == 0:
    print("Số chẵn")
else:
    print("Số lẻ")
# Out:
# Số lẻ

# %% [markdown]
# W1A8: Đoạn code này tạo vòng lặp in ra 3 lần với thông báo động viên học tập.
# Kết quả khi chạy:
# AI đang học lần 1
# Huấn luyện xong!
# AI đang học lần 2
# Huấn luyện xong!
# AI đang học lần 3
# Huấn luyện xong!
# Giải thích chi tiết:
# 1. for i in range(3): - Vòng lặp chạy 3 lần (i = 0, 1, 2)
# 2. print("AI đang học lần", i + 1) - In số lần học (cộng 1 vì i bắt đầu từ 0)
# 3. print("Huấn luyện xong!") - In thông báo hoàn thành sau mỗi lần
# Ý nghĩa của code:
# Code này mô phỏng quá trình huấn luyện AI qua nhiều lần lặp (epoch), thường gặp trong machine learning. Trong thực tế, mỗi lần lặp sẽ có các phép tính phức tạp hơn nhiều.

# %%
for i in range(3):
    print("AI đang học lần", i+1)
    print("Huấn luyện xong!")
# Out:
# AI đang học lần 1
# Huấn luyện xong!
# AI đang học lần 2
# Huấn luyện xong!
# AI đang học lần 3
# Huấn luyện xong!

# %% [markdown]
# W1A9: Đoạn code này in ra dự đoán về các con vật bằng cách lặp qua danh sách.
# Kết quả khi chạy in ra 3 dòng:
# Dự đoán con vật: cat
# Dự đoán con vật: dog
# Dự đoán con vật: fish
# Giải thích:
# 1. for x in ["cat", "dog", "fish"]: - Vòng lặp qua từng phần tử trong danh sách
# 2. print("Dự đoán con vật:", x) - In ra dự đoán cho mỗi con vật

# %%
for x in ["cat", "dog", "fish"]:
    print("Dự đoán con vật:", x)
# Out:
# Dự đoán con vật: cat
# Dự đoán con vật: dog
# Dự đoán con vật: fish

# %% [markdown]
# W1A10: Đoạn code này có lỗi cú pháp và cần sửa để chạy đúng.
# Lỗi trong code:
# 1. Dấu ngoặc kép không khớp: print "=== AI Prediction System ===" thiếu dấu ngoặc đơn ()
# 2. Dấu ngoặc kép thừa: print("2) Weather forecast")) có 2 dấu đóng ngoặc
# 3. Thiếu dấu ngoặc đơn: Tất cả các lệnh print phải có cú pháp print(...)

# %%
 # Simple menu
print("=== AI Prediction System ===")
print("1) Sentiment analysis")
print("2) Weather forecast")
print("3) Exit")
print("Please choose an option:")
# Out:
# === AI Prediction System ===
# 1) Sentiment analysis
# 2) Weather forecast
# 3) Exit
# Please choose an option:
