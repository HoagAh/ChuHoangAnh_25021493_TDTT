# %% [markdown]
# W1A1: Đoạn mã này thực hiện một kịch bản lập trình rất cơ bản:
#
# Khởi tạo dữ liệu: Gán hai giá trị số nguyên (7 và 5) cho hai biến (a và b).
#
# Xử lý dữ liệu: Thực hiện phép toán trừ (a - b).
#
# Lưu trữ kết quả: Gán kết quả của phép trừ vào một biến mới (c).
#
# Xuất kết quả: Hiển thị giá trị của biến kết quả (c) ra màn hình.

# %%
a = 7
b = 5
c = a - b
print(c)
# Out:
# 2
