# %% [markdown]
# W2A1:

# %%
print("[Hello World!]")
# Out:
# [Hello World!]

# %% [markdown]
# W2A2:

# %%
name = input()
print("Xin chao", name)
# Out:
# Xin chao Chu Hoang Anh

# %% [markdown]
# W2A3:

# %%
a, b = map(int, input().split())
print(a + b)
print(a - b)
print(a * b)
print(a // b)
print(a % b)
print(f"{a / b:.2f}")
# Out:
# 10
# -4
# 21
# 0
# 3
# 0.43

# %% [markdown]
# W2A4:

# %%
a1, b1, c1, a2, b2, a3 = map(int, input().split())
TB = ((a1+b1+c1)+(a2+b2)*2 +a3*3)/10
ket_qua = round(TB,1)
print(ket_qua)
# Out:
# 7.9

# %% [markdown]
# W2A5

# %%
a, b = map(int, input().split())
print(a**b)
# Out:
# 64

# %% [markdown]
# W2A6

# %%
so = input()
if len(so) == 1:
    print(ord(so))
    print(so.upper())
else:
    print("Ky tu khong hop le")
# Out:
# 97
# A

# %% [markdown]
# W2A7

# %%
A = ((13**2)*3) + 5
B = 13**2*3 + 5
print(A, B)
# Out:
# 512 512

# %% [markdown]
# W2A8

# %%
c = float(input())
f = 9/5 * c + 32
print(f"{f:.2f}")
# Out:
# 64.40

# %% [markdown]
# W2A9:

# %%
gia_tri = float(input("Gia tri: "))
if gia_tri < 0:
    print("Gia tri khong hop le")
else:
    tong = (gia_tri + 10) + (gia_tri * 0.1) + ((gia_tri +10) * 0.3)
    ket_qua = round(tong, 2)
    print(ket_qua)
# Out:
# 44.36

# %% [markdown]
# W2A10:

# %%
a, b, c = map(str, input().split())
print("Hi",c,",", b,"and", a)
# Out:
# Hi Helen , Alice and Bob

# %% [markdown]
# W2A11:

# %%
a, b = map(int, input().split())
if a >= 0 and a <= 24 and b >= 0 and b <= 60:
    second1 = a * 3600
    second2 = b * 60
    print(second1, second2)
else:
    print("Gio hoac phut khong hop le")
# Out:
# 72000 3600

# %% [markdown]
# W2A12:

# %%
a = int(input())
print(6 * a**2)
# Out:
# 6

# %% [markdown]
# W2A13:

# %%
a, b = map(int, input().split())
if a > 0 and b > 0:
    units_digit = (a * b) % 10
    print(units_digit)
else:
    print("Vui long nhap gia tri duong")
# Out:
# 5

# %% [markdown]
# W2A14:

# %%
a, b = map(int, input().split())
a, b = b, a
print(a, b)
# Out:
# 2 1

# %% [markdown]
# W2A15

# %%
n = int(input())
star_number = 6 *n * (n - 1) + 1
print(star_number)
print(f"Day {n} co so sao dau tien:")
for i in range(1, n + 1):
    s = 6 * i * (i - 1) + 1
print(f"S({i} = {s})")
# Out:
# 73
# Day 4 co so sao dau tien:
# S(4 = 73)

# %% [markdown]
# W2A16:

# %%
print("Spring\nSummer\nFall\nWinter")
# Out:
# Spring
# Summer
# Fall
# Winter

# %% [markdown]
# W217:

# %%
print("*\n***\n*****")
# Out:
# *
# ***
# *****

# %% [markdown]
# W2A18:

# %%
print("### ##  ### ###")
print(" #  # #  #   #")
print(" #  # #  #   #")
print(" #  # #  #   #")
print(" #  ##   #   #")
# Out:
# ### ##  ### ###
#  #  # #  #   #
#  #  # #  #   #
#  #  # #  #   #
#  #  ##   #   #

# %% [markdown]
# W2A19:

# %%
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# W2A20:

# %%
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# w2A21:

# %%
#print("Hello, world\nHello, world\nHello, world\nHello, world\nHello, world\nHello, world\nHello, world\nHello, world\nHello, world\nHello, world\n")

a = "Hello, world"
lap_lai = 10
for i in range(lap_lai):
    print(a)
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
